# %% [markdown]
# ##Setting up the enviroment (to all models)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
# Código para leer el dataset desde google drive
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
#Autenticar la cuenta
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':'1FyF_Ut7WUxJ56FarHsxYbpY_DtN3HNLB'}) 
downloaded.GetContentFile('LSM_reduced.csv') 
data = pd.read_csv('LSM_reduced.csv')

# %%
target= np.full((500,1),30)
for i in np.arange(21):
    aux = np.full((500,1),i)
    target = np.vstack((target,aux))
    
target = np.delete(target,slice(0,500),0)
target=target.reshape(10500)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2,random_state=0,stratify=target)

X_train=np.array(X_train,dtype='int')
X_test=np.array(X_test,dtype='int')

X_train=X_train/255
X_test=X_test/255

# %%
def one_hot(x, n_clases=21):
  r=np.zeros((x.shape[0],n_clases))
  for i in np.arange(n_clases):
    r[:,i]=(x==i)*1
  return r

# %%
y_orig=y_test
y_test=one_hot(y_test)
y_train=one_hot(y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_validate,y_train,y_validate=train_test_split(X_train,y_train,test_size=0.15,random_state=0)

# %%
X_train=X_train.reshape(X_train.shape[0],*(72,88,1))
X_test=X_test.reshape(X_test.shape[0],*(72,88,1))
X_validate=X_validate.reshape(X_validate.shape[0],*(72,88,1))

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from keras.optimizers import Adam

# %%
classes = 21
epochs = 30
batch_size = 128

# %% [markdown]
# ##CNN validation and train

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(72, 88, 1), padding='same'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=4, activation='relu', strides=3))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=4, activation='relu', strides=3))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(classes, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
import time
start = time.time()
history = model.fit(X_train, y_train, 
                   validation_data=(X_validate, y_validate),
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 47s 809ms/step - loss: 3.0490 - accuracy: 0.0473 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 3.0440 - val_accuracy: 0.0413 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/30
# 56/56 [==============================] - 44s 794ms/step - loss: 3.0144 - accuracy: 0.0700 - f1_m: 0.0010 - precision_m: 0.0278 - recall_m: 5.2256e-04 - val_loss: 2.7497 - val_accuracy: 0.1579 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 3/30
# 56/56 [==============================] - 45s 803ms/step - loss: 2.5149 - accuracy: 0.2240 - f1_m: 0.0514 - precision_m: 0.4986 - recall_m: 0.0279 - val_loss: 1.9031 - val_accuracy: 0.4079 - val_f1_m: 0.1908 - val_precision_m: 0.7663 - val_recall_m: 0.1095
# Epoch 4/30
# 56/56 [==============================] - 45s 805ms/step - loss: 1.7000 - accuracy: 0.4563 - f1_m: 0.3119 - precision_m: 0.7402 - recall_m: 0.2011 - val_loss: 1.2042 - val_accuracy: 0.6706 - val_f1_m: 0.4592 - val_precision_m: 0.8902 - val_recall_m: 0.3110
# Epoch 5/30
# 56/56 [==============================] - 46s 815ms/step - loss: 1.0046 - accuracy: 0.6823 - f1_m: 0.6375 - precision_m: 0.8443 - recall_m: 0.5149 - val_loss: 0.7501 - val_accuracy: 0.8071 - val_f1_m: 0.7346 - val_precision_m: 0.9238 - val_recall_m: 0.6104
# Epoch 6/30
# 56/56 [==============================] - 46s 827ms/step - loss: 0.6295 - accuracy: 0.7919 - f1_m: 0.7775 - precision_m: 0.8638 - recall_m: 0.7079 - val_loss: 0.6343 - val_accuracy: 0.8151 - val_f1_m: 0.7669 - val_precision_m: 0.9003 - val_recall_m: 0.6683
# 56/56 [==============================] - 45s 798ms/step - loss: 0.0650 - accuracy: 0.9770 - f1_m: 0.9773 - precision_m: 0.9790 - recall_m: 0.9756 - val_loss: 0.0977 - val_accuracy: 0.9714 - val_f1_m: 0.9708 - val_precision_m: 0.9742 - val_recall_m: 0.9674
# Epoch 27/30
# 56/56 [==============================] - 45s 800ms/step - loss: 0.0518 - accuracy: 0.9824 - f1_m: 0.9827 - precision_m: 0.9841 - recall_m: 0.9814 - val_loss: 0.1015 - val_accuracy: 0.9683 - val_f1_m: 0.9670 - val_precision_m: 0.9697 - val_recall_m: 0.9643
# Epoch 28/30
# 56/56 [==============================] - 45s 799ms/step - loss: 0.0559 - accuracy: 0.9815 - f1_m: 0.9815 - precision_m: 0.9824 - recall_m: 0.9807 - val_loss: 0.1879 - val_accuracy: 0.9381 - val_f1_m: 0.9388 - val_precision_m: 0.9475 - val_recall_m: 0.9302
# Epoch 29/30
# 56/56 [==============================] - 45s 798ms/step - loss: 0.0611 - accuracy: 0.9788 - f1_m: 0.9785 - precision_m: 0.9806 - recall_m: 0.9763 - val_loss: 0.0830 - val_accuracy: 0.9754 - val_f1_m: 0.9754 - val_precision_m: 0.9794 - val_recall_m: 0.9714
# Epoch 30/30
# 56/56 [==============================] - 45s 801ms/step - loss: 0.0420 - accuracy: 0.9858 - f1_m: 0.9860 - precision_m: 0.9874 - recall_m: 0.9847 - val_loss: 0.0861 - val_accuracy: 0.9714 - val_f1_m: 0.9719 - val_precision_m: 0.9738 - val_recall_m: 0.9700
# Time taken to train model:  1353.488380432129

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Accuracy and loss plot')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train accuracy', 'validation accuracy','loss train','loss accuracy'])
plt.show()

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Accuracy: " + str(accuracy_score(y_test, prediction.round())))
# Out:
# Test Accuracy: 0.9628571428571429

# %%
labels=["A","B","C","D","E","F","G","H","I","L","M","N","O","P","R","S","T","U","V","W","Y"]
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction, target_names=labels))

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred=model.predict_classes(X_test)
cm=confusion_matrix(y_orig,y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm,annot=True,cmap='rocket_r')
plt.xlabel('Etiquetas Originales')
plt.ylabel('Predicciones')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Text(87.0, 0.5, 'Predicciones')

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_model/assets

# %%
#import tensorflow as tf
#new_model = tf.keras.models.load_model('saved_model/my_model')

# Check its architecture
#new_model.summary()

# %%
model.save('my_modelh5.h5')

# %% [markdown]
# ##CNN AlexNet

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np

np.random.seed(1000)

#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer
AlexNet.add(Conv2D(filters=96, input_shape=(72,88,1), kernel_size=(11,11), strides=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())
# 1st Fully Connected Layer
AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1000))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(21))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 18, 22, 96)        11712
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 18, 22, 96)        384
# _________________________________________________________________
# activation_18 (Activation)   (None, 18, 22, 96)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 9, 11, 96)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 9, 11, 256)        614656
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 9, 11, 256)        1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 9, 11, 256)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 6, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 5, 6, 384)         885120
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 5, 6, 384)         1536
# _________________________________________________________________
# activation_20 (Activation)   (None, 5, 6, 384)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 5, 6, 384)         1327488
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 5, 6, 384)         1536
# _________________________________________________________________
# activation_21 (Activation)   (None, 5, 6, 384)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 5, 6, 256)         884992
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 5, 6, 256)         1024
# _________________________________________________________________
# activation_22 (Activation)   (None, 5, 6, 256)         0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4096)              9441280
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_23 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_24 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1000)              4097000
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_25 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 21)                21021
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 21)                84
# _________________________________________________________________
# activation_26 (Activation)   (None, 21)                0
# =================================================================
# Total params: 34,106,937
# Trainable params: 34,085,759
# Non-trainable params: 21,178
# _________________________________________________________________

# %%
AlexNet.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
#Learning Rate Annealer
from keras.callbacks import ReduceLROnPlateau
lrr= ReduceLROnPlateau(   monitor='val_acc',   factor=.01,   patience=3,  min_lr=1e-5)

# %%
#Defining the parameters
batch_size= 128
epochs=30
#learn_rate=.001

# %%
#Training the model
import time
start = time.time()
history_alexNet = AlexNet.fit(X_train, y_train, 
                   validation_data=(X_validate, y_validate),
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 4s 50ms/step - loss: 1.9941 - accuracy: 0.4495 - f1_m: 0.2294 - precision_m: 0.8028 - recall_m: 0.1472 - val_loss: 5.5835 - val_accuracy: 0.0476 - val_f1_m: 0.0477 - val_precision_m: 0.0477 - val_recall_m: 0.0477
# Epoch 2/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0.6174 - accuracy: 0.9115 - f1_m: 0.8134 - precision_m: 0.9722 - recall_m: 0.7015 - val_loss: 7.3716 - val_accuracy: 0.0476 - val_f1_m: 0.0477 - val_precision_m: 0.0477 - val_recall_m: 0.0477
# Epoch 3/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0.3746 - accuracy: 0.9687 - f1_m: 0.9212 - precision_m: 0.9884 - recall_m: 0.8630 - val_loss: 6.3042 - val_accuracy: 0.0476 - val_f1_m: 0.0477 - val_precision_m: 0.0477 - val_recall_m: 0.0477
# Epoch 4/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0.3259 - accuracy: 0.9721 - f1_m: 0.9408 - precision_m: 0.9884 - recall_m: 0.8982 - val_loss: 7.4898 - val_accuracy: 0.0476 - val_f1_m: 0.0477 - val_precision_m: 0.0477 - val_recall_m: 0.0477
# Epoch 5/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0.2509 - accuracy: 0.9818 - f1_m: 0.9649 - precision_m: 0.9935 - recall_m: 0.9381 - val_loss: 7.2651 - val_accuracy: 0.0476 - val_f1_m: 0.0477 - val_precision_m: 0.0477 - val_recall_m: 0.0477
# Epoch 6/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0
# 56/56 [==============================] - 2s 43ms/step - loss: 0.0341 - accuracy: 0.9977 - f1_m: 0.9979 - precision_m: 0.9984 - recall_m: 0.9974 - val_loss: 0.2926 - val_accuracy: 0.9317 - val_f1_m: 0.9203 - val_precision_m: 0.9614 - val_recall_m: 0.8828
# Time taken to train model:  75.02817630767822

# %%
#After successful training, we will visualize its performance.

import matplotlib.pyplot as plt
#Plotting the training and validation loss

f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

#Assigning the first subplot to graph training loss and validation loss
ax[0].plot(history_alexNet.history['loss'],color='b',label='Training Loss')
ax[0].plot(history_alexNet.history['val_loss'],color='r',label='Validation Loss')

#Plotting the training accuracy and validation accuracy
ax[1].plot(history_alexNet.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(history_alexNet.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %% [markdown]
# ##CNN AlexNet 1st Variation

# %%
model=Sequential()
model.add(Conv2D(64,kernel_size=(3,3),input_shape=(72,88,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.20))
model.add(Dense(21, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 70, 86, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 35, 43, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 33, 41, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 20, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 18, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 9, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4032)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               516224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                2709
# =================================================================
# Total params: 593,429
# Trainable params: 593,429
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy',f1_m,precision_m, recall_m])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ff9d5c708f18> in <module>()
# ----> 1 model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy',f1_m,precision_m, recall_m])
#
# NameError: name 'f1_m' is not defined

# %%
batch_size = 128
epochs = 30

# %%
import time
start = time.time()
history = model.fit(X_train, y_train, 
                   validation_data=(X_validate, y_validate),
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 3s 46ms/step - loss: 3.0462 - accuracy: 0.0505 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 3.0196 - val_accuracy: 0.1143 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/30
# 56/56 [==============================] - 2s 37ms/step - loss: 2.8672 - accuracy: 0.1369 - f1_m: 0.0070 - precision_m: 0.1077 - recall_m: 0.0037 - val_loss: 2.1879 - val_accuracy: 0.3738 - val_f1_m: 0.0868 - val_precision_m: 0.5907 - val_recall_m: 0.0470
# Epoch 3/30
# 56/56 [==============================] - 2s 37ms/step - loss: 2.0226 - accuracy: 0.3796 - f1_m: 0.1905 - precision_m: 0.7016 - recall_m: 0.1130 - val_loss: 1.3321 - val_accuracy: 0.6278 - val_f1_m: 0.4977 - val_precision_m: 0.8559 - val_recall_m: 0.3515
# Epoch 4/30
# 56/56 [==============================] - 2s 37ms/step - loss: 1.2892 - accuracy: 0.6019 - f1_m: 0.5202 - precision_m: 0.8260 - recall_m: 0.3832 - val_loss: 0.8245 - val_accuracy: 0.7659 - val_f1_m: 0.7268 - val_precision_m: 0.8952 - val_recall_m: 0.6123
# Epoch 5/30
# 56/56 [==============================] - 2s 38ms/step - loss: 0.8632 - accuracy: 0.7255 - f1_m: 0.7042 - precision_m: 0.8604 - recall_m: 0.5975 - val_loss: 0.5587 - val_accuracy: 0.8516 - val_f1_m: 0.8334 - val_precision_m: 0.9283 - val_recall_m: 0.7567
# Epoch 6/30
# 56/56 [==============================] - 2s 37ms/step - loss: 0.6171 - accuracy: 0.8029 - f1_m: 0.7994 - precision_m: 0.8879 - recall_m: 0.7277 - val_loss: 0.4381 - val_accuracy: 0.8690 - val_f1_m: 0.8656 - val_precision_m: 0.9308 - val_recall_m: 0.8093
# Epoch 7/30
# 56/56 [==============================] - 2s 37ms/step - loss: 0.
30
# 56/56 [==============================] - 2s 38ms/step - loss: 0.0399 - accuracy: 0.9898 - f1_m: 0.9899 - precision_m: 0.9916 - recall_m: 0.9881 - val_loss: 0.1282 - val_accuracy: 0.9651 - val_f1_m: 0.9649 - val_precision_m: 0.9665 - val_recall_m: 0.9633
# Epoch 30/30
# 56/56 [==============================] - 2s 38ms/step - loss: 0.0447 - accuracy: 0.9867 - f1_m: 0.9868 - precision_m: 0.9882 - recall_m: 0.9854 - val_loss: 0.1282 - val_accuracy: 0.9722 - val_f1_m: 0.9733 - val_precision_m: 0.9740 - val_recall_m: 0.9725
# Time taken to train model:  64.54169464111328

# %%
f,ax=plt.subplots(2,1) 

ax[0].plot(history.history['loss'],color='b',label='Training Loss')
ax[0].plot(history.history['val_loss'],color='r',label='Validation Loss')

ax[1].plot(history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %% [markdown]
# ##CNN AlexNet 2nd Variation

# %%
classes = 21
epochs = 30
batch_size = 128

# %%
model1 = Sequential()

model1.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(72, 88, 1), padding='same'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(64, kernel_size=4, activation='relu', strides=3))
model1.add(Dropout(0.25))

model1.add(Conv2D(128, kernel_size=4, activation='relu', strides=3))
model1.add(Dropout(0.25))

model1.add(Flatten())
model1.add(Dense(256, activation='relu'))
model1.add(Dense(classes, activation='softmax'))

model1.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.001), metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 72, 88, 32)        544
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 72, 88, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 44, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 14, 64)        32832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11, 14, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 4, 128)         131200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1536)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               393472
# _________________________________________________________________
# dense_5 (Dense)              (None, 21)                5397
# =================================================================
# Total params: 563,445
# Trainable params: 563,445
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
start = time.time()
history1 = model1.fit(X_train, y_train, 
                   validation_data=(X_validate, y_validate),
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 3s 33ms/step - loss: 3.0485 - accuracy: 0.0445 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 3.0428 - val_accuracy: 0.0452 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/30
# 56/56 [==============================] - 1s 24ms/step - loss: 2.9960 - accuracy: 0.0770 - f1_m: 0.0014 - precision_m: 0.0302 - recall_m: 7.2705e-04 - val_loss: 2.6707 - val_accuracy: 0.2048 - val_f1_m: 0.0465 - val_precision_m: 0.4165 - val_recall_m: 0.0247
# Epoch 3/30
# 56/56 [==============================] - 1s 24ms/step - loss: 2.4683 - accuracy: 0.2469 - f1_m: 0.0640 - precision_m: 0.5852 - recall_m: 0.0346 - val_loss: 1.9179 - val_accuracy: 0.4540 - val_f1_m: 0.1592 - val_precision_m: 0.7072 - val_recall_m: 0.0903
# Epoch 4/30
# 56/56 [==============================] - 1s 25ms/step - loss: 1.8352 - accuracy: 0.4230 - f1_m: 0.2647 - precision_m: 0.7101 - recall_m: 0.1650 - val_loss: 1.3879 - val_accuracy: 0.5960 - val_f1_m: 0.3925 - val_precision_m: 0.8877 - val_recall_m: 0.2526
# Epoch 5/30
# 56/56 [==============================] - 1s 24ms/step - loss: 1.3493 - accuracy: 0.5672 - f1_m: 0.4926 - precision_m: 0.8004 - recall_m: 0.3594 - val_loss: 0.9550 - val_accuracy: 0.7540 - val_f1_m: 0.6121 - val_precision_m: 0.9166 - val_recall_m: 0.4600
# Epoch 6/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.9180 - accuracy: 0.6960 - f1_m: 0.6692 - precision_m: 0.8290 - recall_m: 0.5626 - val_loss: 0.7757 - val_accuracy: 0.8071 - val_f1_m: 0.7210 - val_precision_m: 0.9330 - val_recall_m: 0.5881
# Epoch 7/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.
30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.0684 - accuracy: 0.9760 - f1_m: 0.9766 - precision_m: 0.9797 - recall_m: 0.9736 - val_loss: 0.1110 - val_accuracy: 0.9659 - val_f1_m: 0.9663 - val_precision_m: 0.9705 - val_recall_m: 0.9622
# Epoch 30/30
# 56/56 [==============================] - 1s 24ms/step - loss: 0.0851 - accuracy: 0.9703 - f1_m: 0.9702 - precision_m: 0.9723 - recall_m: 0.9682 - val_loss: 0.1159 - val_accuracy: 0.9635 - val_f1_m: 0.9656 - val_precision_m: 0.9722 - val_recall_m: 0.9591
# Time taken to train model:  42.34285044670105

# %%
f,ax=plt.subplots(2,1) 

ax[0].plot(history1.history['loss'],color='b',label='Training Loss')
ax[0].plot(history1.history['val_loss'],color='r',label='Validation Loss')

ax[1].plot(history1.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(history1.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['loss'])
plt.title('Accuracy plot')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['accuracy','loss'])
plt.show()

# %%
prediction1 = model1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Accuracy: " + str(accuracy_score(y_test, prediction.round())))
# Out:
# Test Accuracy: 0.9628571428571429

# %%
# !mkdir -p saved_model
model.save('saved_model/cnn_train_test') 
#model.save('my_modelh5.h5')
# Out:
# INFO:tensorflow:Assets written to: saved_model/cnn_train_test/assets

# %%
import tensorflow as tf
new_model = tf.keras.models.load_model('saved_model/cnn_train_test')

# Check its architecture
new_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 72, 88, 32)        544
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 72, 88, 32)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 36, 44, 32)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 11, 14, 64)        32832
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 11, 14, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 3, 4, 128)         131200
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 3, 4, 128)         0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 1536)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               393472
# _________________________________________________________________
# dense_29 (Dense)             (None, 21)                5397
# =================================================================
# Total params: 563,445
# Trainable params: 563,445
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred=model.predict_classes(X_test)
cm=confusion_matrix(y_orig,y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm,annot=True,cmap='rocket_r')
plt.xlabel('Etiquetas Originales')
plt.ylabel('Predicciones')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Text(87.0, 0.5, 'Predicciones')

# %% [markdown]
# ##Comparativas

# %%
plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
plt.plot(history_alexNet.history['val_accuracy'],color='r',label='validation AlexNet')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],color='b',label='accuracy 1st variant')
plt.plot(history.history['val_accuracy'],color='r',label='validation accuracy 1st variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history1.history['accuracy'],color='b',label='accuracy 2nd variant')
plt.plot(history1.history['val_accuracy'],color='r',label='validation accuracy 2nd variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
plt.plot(history_alexNet.history['val_accuracy'],color='r',label='validation AlexNet')
plt.plot(history.history['accuracy'],color='g',label='accuracy 1st variant')
plt.plot(history.history['val_accuracy'],color='c',label='validation accuracy 1st variant')
plt.plot(history1.history['accuracy'],color='y',label='accuracy 2nd variant')
plt.plot(history1.history['val_accuracy'],color='k',label='validation accuracy 2nd variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['val_accuracy'],color='b',label='validation accuracy AlexNet')
plt.plot(history.history['val_accuracy'],color='r',label='validation accuracy 1st variant')
plt.plot(history1.history['val_accuracy'],color='g',label='validation accuracy 2nd variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
plt.plot(history.history['accuracy'],color='g',label='accuracy 1st variant')
plt.plot(history1.history['accuracy'],color='y',label='accuracy 2nd variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['val_loss'],color='b',label='validation loss AlexNet')
plt.plot(history.history['val_loss'],color='r',label='validation loss 1st variant')
plt.plot(history1.history['val_loss'],color='g',label='validation loss 2nd variant')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['loss'],color='b',label='loss AlexNet')
plt.plot(history.history['loss'],color='r',label='loss 1st variant')
plt.plot(history1.history['loss'],color='g',label='loss 2nd variant')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %% [markdown]
# #Accuracy of all models without validation set

# %% [markdown]
# ##AlexNet

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np

#np.random.seed(1000)

#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer
AlexNet.add(Conv2D(filters=96, input_shape=(72,88,1), kernel_size=(11,11), strides=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())
# 1st Fully Connected Layer
AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1000))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(21))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

# %%
AlexNet.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
import time
start = time.time()
history_alexNet = AlexNet.fit(X_train, y_train,
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 4s 42ms/step - loss: 1.9491 - accuracy: 0.4731 - f1_m: 0.2318 - precision_m: 0.7953 - recall_m: 0.1507
# Epoch 2/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.5653 - accuracy: 0.9225 - f1_m: 0.8431 - precision_m: 0.9805 - recall_m: 0.7407
# Epoch 3/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.3700 - accuracy: 0.9699 - f1_m: 0.9259 - precision_m: 0.9888 - recall_m: 0.8710
# Epoch 4/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2806 - accuracy: 0.9819 - f1_m: 0.9584 - precision_m: 0.9934 - recall_m: 0.9261
# Epoch 5/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2349 - accuracy: 0.9863 - f1_m: 0.9734 - precision_m: 0.9943 - recall_m: 0.9535
# Epoch 6/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.2002 - accuracy: 0.9907 - f1_m: 0.9798 - precision_m: 0.9955 - recall_m: 0.9648
# Epoch 7/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1710 - accuracy: 0.9917 - f1_m: 0.9869 - precision_m: 0.9962 - recall_m: 0.9780
# Epoch 8/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1574 - accuracy: 0.9923 - f1_m: 0.9877 - precision_m: 0.9961 - recall_m: 0.9796
# Epoch 9/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.1357 - accuracy: 0.9949 - f1_m: 0.9926 - precision_m: 0.9968 - recall_m: 0.9885
# Epoch 10/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.1161 - accuracy: 0.9970 - f1_m: 0.9944 - precision_m: 0.9976 - recall_m: 0.9912
# Epoch 11/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.1080 - accuracy: 0.9979 - f1_m: 0.9961 - precision_m: 0.9991 - recall_m: 0.9931
# Epoch 12/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0967 - accuracy: 0.9975 - f1_m: 0.9966 - precision_m: 0.9983 - recall_m: 0.9950
# Epoch 13/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.1040 - accuracy: 0.9950 - f1_m: 0.9939 - precision_m: 0.9973 - recall_m: 0.9906
# Epoch 14/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0880 - accuracy: 0.9974 - f1_m: 0.9956 - precision_m: 0.9989 - recall_m: 0.9923
# Epoch 15/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0785 - accuracy: 0.9980 - f1_m: 0.9980 - precision_m: 0.9988 - recall_m: 0.9971
# Epoch 16/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0903 - accuracy: 0.9940 - f1_m: 0.9915 - precision_m: 0.9951 - recall_m: 0.9879
# Epoch 17/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0820 - accuracy: 0.9931 - f1_m: 0.9926 - precision_m: 0.9951 - recall_m: 0.9902
# Epoch 18/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0668 - accuracy: 0.9971 - f1_m: 0.9968 - precision_m: 0.9982 - recall_m: 0.9955
# Epoch 19/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0567 - accuracy: 0.9998 - f1_m: 0.9991 - precision_m: 0.9999 - recall_m: 0.9983
# Epoch 20/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0484 - accuracy: 0.9998 - f1_m: 0.9998 - precision_m: 0.9998 - recall_m: 0.9998
# Epoch 21/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0441 - accuracy: 0.9997 - f1_m: 0.9996 - precision_m: 0.9998 - recall_m: 0.9994
# Epoch 22/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0450 - accuracy: 0.9990 - f1_m: 0.9990 - precision_m: 0.9992 - recall_m: 0.9989
# Epoch 23/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0660 - accuracy: 0.9942 - f1_m: 0.9933 - precision_m: 0.9956 - recall_m: 0.9912
# Epoch 24/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.0619 - accuracy: 0.9952 - f1_m: 0.9952 - precision_m: 0.9969 - recall_m: 0.9935
# Epoch 25/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0403 - accuracy: 0.9992 - f1_m: 0.9983 - precision_m: 0.9994 - recall_m: 0.9972
# Epoch 26/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0496 - accuracy: 0.9974 - f1_m: 0.9966 - precision_m: 0.9976 - recall_m: 0.9957
# Epoch 27/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0426 - accuracy: 0.9986 - f1_m: 0.9985 - precision_m: 0.9988 - recall_m: 0.9983
# Epoch 28/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0406 - accuracy: 0.9975 - f1_m: 0.9971 - precision_m: 0.9978 - recall_m: 0.9964
# Epoch 29/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0341 - accuracy: 0.9990 - f1_m: 0.9987 - precision_m: 0.9990 - recall_m: 0.9984
# Epoch 30/30
# 56/56 [==============================] - 2s 40ms/step - loss: 0.0343 - accuracy: 0.9982 - f1_m: 0.9984 - precision_m: 0.9987 - recall_m: 0.9980
# Time taken to train model:  69.99506759643555

# %%
plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06f6a3cacde8> in <module>()
# ----> 1 plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
#       2 plt.xlabel('epochs')
#       3 plt.ylabel('accuracy')
#       4 #plt.legend(['accuracy','loss'])
#       5 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
plt.plot(history_alexNet.history['loss'],color='b',label='loss AlexNet')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
prediction_AlexNet = AlexNet.predict(X_test)
from sklearn.metrics import accuracy_score
print("Test Accuracy: " + str(accuracy_score(y_test, prediction_AlexNet.round())))
labels=["A","B","C","D","E","F","G","H","I","L","M","N","O","P","R","S","T","U","V","W","Y"]
# Out:
# Test Accuracy: 0.2319047619047619

# %% [markdown]
# ##CNN 1st variation

# %%
model=Sequential()
model.add(Conv2D(64,kernel_size=(3,3),input_shape=(72,88,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.20))
model.add(Dense(21, activation = 'softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
import time
start = time.time()
history = model.fit(X_train, y_train,
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 2s 34ms/step - loss: 3.0461 - accuracy: 0.0533 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 2/30
# 56/56 [==============================] - 2s 34ms/step - loss: 2.8044 - accuracy: 0.1468 - f1_m: 0.0195 - precision_m: 0.2692 - recall_m: 0.0104
# Epoch 3/30
# 56/56 [==============================] - 2s 34ms/step - loss: 1
30
# 56/56 [==============================] - 2s 34ms/step - loss: 0.0619 - accuracy: 0.9779 - f1_m: 0.9777 - precision_m: 0.9804 - recall_m: 0.9750
# Epoch 29/30
# 56/56 [==============================] - 2s 34ms/step - loss: 0.0592 - accuracy: 0.9797 - f1_m: 0.9798 - precision_m: 0.9827 - recall_m: 0.9771
# Epoch 30/30
# 56/56 [==============================] - 2s 34ms/step - loss: 0.0484 - accuracy: 0.9848 - f1_m: 0.9847 - precision_m: 0.9867 - recall_m: 0.9828
# Time taken to train model:  58.11063075065613

# %%
plt.plot(history.history['accuracy'],color='b',label='accuracy 1st variation')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='b',label='loss AlexNet')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
prediction_model = model.predict(X_test)
from sklearn.metrics import accuracy_score
print("Test Accuracy: " + str(accuracy_score(y_test, prediction_model.round())))
labels=["A","B","C","D","E","F","G","H","I","L","M","N","O","P","R","S","T","U","V","W","Y"]
# Out:
# Test Accuracy: 0.9680952380952381

# %% [markdown]
# ##CNN 2nd variation

# %%
model1 = Sequential()

model1.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(72, 88, 1), padding='same'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(64, kernel_size=4, activation='relu', strides=3))
model1.add(Dropout(0.25))

model1.add(Conv2D(128, kernel_size=4, activation='relu', strides=3))
model1.add(Dropout(0.25))

model1.add(Flatten())
model1.add(Dense(256, activation='relu'))
model1.add(Dense(classes, activation='softmax'))

model1.compile(loss="categorical_crossentropy", optimizer=Adam(lr=0.001), metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
import time
start = time.time()
history1 = model1.fit(X_train, y_train,
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 2s 23ms/step - loss: 3.0475 - accuracy: 0.0526 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 2/30
# 56/56 [==============================] - 1s 22ms/step - loss: 2.9443 - accuracy: 0.0958 - f1_m: 0.0034 - precision_m: 0.0629 - recall_m: 0.0018
# Epoch 3/30
# 56/56 [==============================] - 1s 22ms/step - loss: 2.3538 - accuracy: 0.2757 - f1_m: 0.0902 - precision_m: 0.6368 - recall_m: 0.0499
# Epoch 4/30
# 56/56 [==============================] - 1s 22ms/step - loss: 1.6034 - accuracy: 0.4985 - f1_m: 0.3704 - precision_m: 0.7897 - recall_m: 0.2464
# Epoch 5/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.9877 - accuracy: 0.6856 - f1_m: 0.6516 - precision_m: 0.8416 - recall_m: 0.5341
# Epoch 6/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6108 - accuracy: 0.7971 - f1_m: 0.7894 - precision_m: 0.8718 - recall_m: 0.7217
# Epoch 7/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4420 - accuracy: 0.8547 - f1_m: 0.8490 - precision_m: 0.8968 - recall_m: 0.8063
# Epoch 8/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.3132 - accuracy: 0.9025 - f1_m: 0.9002 - precision_m: 0.9299 - recall_m: 0.8724
# Epoch 9/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2780 - accuracy: 0.9030 - f1_m: 0.9019 - precision_m: 0.9242 - recall_m: 0.8808
# Epoch 10/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2139 - accuracy: 0.9270 - f1_m: 0.9252 - precision_m: 0.9386 - recall_m: 0.9122
# Epoch 11/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1999 - accuracy: 0.9331 - f1_m: 0.9324 - precision_m: 0.9464 - recall_m: 0.9190
# Epoch 12/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1599 - accuracy: 0.9456 - f1_m: 0.9447 - precision_m: 0.9538 - recall_m: 0.9358
# Epoch 13/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1322 - accuracy: 0.9577 - f1_m: 0.9569 - precision_m: 0.9660 - recall_m: 0.9481
# Epoch 14/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1315 - accuracy: 0.9533 - f1_m: 0.9534 - precision_m: 0.9605 - recall_m: 0.9465
# Epoch 15/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1187 - accuracy: 0.9577 - f1_m: 0.9582 - precision_m: 0.9649 - recall_m: 0.9517
# Epoch 16/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1034 - accuracy: 0.9676 - f1_m: 0.9673 - precision_m: 0.9738 - recall_m: 0.9609
# Epoch 17/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1025 - accuracy: 0.9637 - f1_m: 0.9634 - precision_m: 0.9669 - recall_m: 0.9599
# Epoch 18/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0978 - accuracy: 0.9628 - f1_m: 0.9627 - precision_m: 0.9666 - recall_m: 0.9589
# Epoch 19/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0804 - accuracy: 0.9720 - f1_m: 0.9723 - precision_m: 0.9759 - recall_m: 0.9687
# Epoch 20/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0746 - accuracy: 0.9746 - f1_m: 0.9739 - precision_m: 0.9765 - recall_m: 0.9713
# Epoch 21/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0678 - accuracy: 0.9761 - f1_m: 0.9763 - precision_m: 0.9794 - recall_m: 0.9732
# Epoch 22/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0762 - accuracy: 0.9718 - f1_m: 0.9721 - precision_m: 0.9740 - recall_m: 0.9702
# Epoch 23/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0704 - accuracy: 0.9746 - f1_m: 0.9748 - precision_m: 0.9768 - recall_m: 0.9728
# Epoch 24/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0612 - accuracy: 0.9787 - f1_m: 0.9777 - precision_m: 0.9802 - recall_m: 0.9753
# Epoch 25/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0603 - accuracy: 0.9789 - f1_m: 0.9789 - precision_m: 0.9804 - recall_m: 0.9774
# Epoch 26/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0581 - accuracy: 0.9768 - f1_m: 0.9773 - precision_m: 0.9789 - recall_m: 0.9758
# Epoch 27/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0559 - accuracy: 0.9799 - f1_m: 0.9798 - precision_m: 0.9818 - recall_m: 0.9779
# Epoch 28/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0502 - accuracy: 0.9831 - f1_m: 0.9832 - precision_m: 0.9845 - recall_m: 0.9820
# Epoch 29/30
# 56/56 [==============================] - 1s 23ms/step - loss: 0.0639 - accuracy: 0.9780 - f1_m: 0.9779 - precision_m: 0.9803 - recall_m: 0.9755
# Epoch 30/30
# 56/56 [==============================] - 1s 22ms/step - loss: 0.0620 - accuracy: 0.9767 - f1_m: 0.9770 - precision_m: 0.9788 - recall_m: 0.9752
# Time taken to train model:  38.65871238708496

# %%
plt.plot(history1.history['accuracy'],color='b',label='accuracy 2nd variation')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history1.history['loss'],color='b',label='loss AlexNet')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
prediction_model1 = model1.predict(X_test)
from sklearn.metrics import accuracy_score
print("Test Accuracy: " + str(accuracy_score(y_test, prediction_model1.round())))
labels=["A","B","C","D","E","F","G","H","I","L","M","N","O","P","R","S","T","U","V","W","Y"]
# Out:
# Test Accuracy: 0.9709523809523809

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred=model1.predict_classes(X_test)
cm=confusion_matrix(y_orig,y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm,annot=True,cmap='rocket_r')
plt.xlabel('Etiquetas Originales')
plt.ylabel('Predicciones')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Text(87.0, 0.5, 'Predicciones')

# %% [markdown]
# ###Comparativas

# %%
plt.plot(history_alexNet.history['accuracy'],color='b',label='accuracy AlexNet')
plt.plot(history.history['accuracy'],color='g',label='accuracy 1st variant')
plt.plot(history1.history['accuracy'],color='y',label='accuracy 2nd variant')
plt.xlabel('epochs')
plt.ylabel('accuracy')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %%
plt.plot(history_alexNet.history['loss'],color='b',label='loss AlexNet')
plt.plot(history.history['loss'],color='g',label='loss 1st variant')
plt.plot(history1.history['loss'],color='y',label='loss 2nd variant')
plt.xlabel('epochs')
plt.ylabel('loss')
#plt.legend(['accuracy','loss'])
plt.legend()
plt.show()

# %% [markdown]
# ##Entrenando el modelo con todo el conjunto de datos

# %%
data=data.to_numpy()
data=data.reshape(data.shape[0],*(72,88,1))

# %%
target=one_hot(target)

# %%
classes = 21
epochs = 30
batch_size = 128

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=4, activation='relu', input_shape=(72, 88, 1), padding='same'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=4, activation='relu', strides=3))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=4, activation='relu', strides=3))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(classes, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
import time
start = time.time()
history = model.fit(data, target, 
                   epochs=epochs,
                   batch_size=batch_size)
training_time = time.time() - start
print("Time taken to train model: ", training_time)
# Out:
# Epoch 1/30
# 83/83 [==============================] - 2s 22ms/step - loss: 5.6887 - accuracy: 0.0614
# Epoch 2/30
# 83/83 [==============================] - 2s 21ms/step - loss: 1.9649 - accuracy: 0.3856
# Epoch 3/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.8229 - accuracy: 0.7284
# Epoch 4/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.4968 - accuracy: 0.8386
# Epoch 5/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.2787 - accuracy: 0.9035
# Epoch 6/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1944 - accuracy: 0.9335
# Epoch 7/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.2779 - accuracy: 0.9102
# Epoch 8/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1476 - accuracy: 0.9483
# Epoch 9/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1015 - accuracy: 0.9655
# Epoch 10/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1821 - accuracy: 0.9422
# Epoch 11/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0910 - accuracy: 0.9713
# Epoch 12/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.1232 - accuracy: 0.9582
# Epoch 13/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0936 - accuracy: 0.9659
# Epoch 14/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1739 - accuracy: 0.9459
# Epoch 15/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0728 - accuracy: 0.9740
# Epoch 16/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0552 - accuracy: 0.9801
# Epoch 17/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0478 - accuracy: 0.9828
# Epoch 18/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.1946 - accuracy: 0.9360
# Epoch 19/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0712 - accuracy: 0.9763
# Epoch 20/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0533 - accuracy: 0.9815
# Epoch 21/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0366 - accuracy: 0.9880
# Epoch 22/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0404 - accuracy: 0.9857
# Epoch 23/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0483 - accuracy: 0.9829
# Epoch 24/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0452 - accuracy: 0.9847
# Epoch 25/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0468 - accuracy: 0.9844
# Epoch 26/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0395 - accuracy: 0.9870
# Epoch 27/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0372 - accuracy: 0.9884
# Epoch 28/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0295 - accuracy: 0.9892
# Epoch 29/30
# 83/83 [==============================] - 2s 21ms/step - loss: 0.0339 - accuracy: 0.9877
# Epoch 30/30
# 83/83 [==============================] - 2s 22ms/step - loss: 0.0572 - accuracy: 0.9818
# Time taken to train model:  55.038743019104004

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Accuracy plot')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['accuracy','loss'])
plt.show()

# %% [markdown]
# ##KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
start_time = time.perf_counter()
knn = KNeighborsClassifier(3) 
knn.fit(X_train, y_train)   
y_pred = knn.predict(X_test)    
acc=accuracy_score(y_test,y_pred)    
print("Exactitud del modelo: ", acc)  
print(time.perf_counter() - start_time, "seconds")
